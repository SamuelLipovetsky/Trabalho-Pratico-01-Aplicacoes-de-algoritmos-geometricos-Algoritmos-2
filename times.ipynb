# %% [markdown]
# ## Testando as funções e comparando o tempo com os metódos de força bruta
# Para garantir que as funções knn e quickSelect foram implementadas corretamene
# foram feitos casos de teste que garantem que o resultado dos métodos de força bruta
# são iguais aos dos métodos implementados

# %%
from aux_functions import keel_dat_reader
from aux_functions import split
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from tests import *

# %%
bf_time,qs_time,elements =test_quickselect()


plt.plot(elements,bf_time,'b--',elements,qs_time,'r--')
plt.ylabel("time")
plt.xlabel("elements")
plt.title("Getting median by execution time")
qs = mpatches.Patch(color='red', label='quickSort')
bf = mpatches.Patch(color='blue', label='Brute force')
plt.legend(handles=[qs,bf])
plt.savefig("./figures/execution_time/quickSelect_bruteForce")
plt.show()

# %%
knn_time,bf_time,elements =test_knn()

plt.plot(elements,knn_time,"rs",alpha=0.9)
plt.plot(elements,bf_time,"b^",alpha=0.9)
plt.ylabel("time")

kd = mpatches.Patch(color='blue', label='Brute force')
bf = mpatches.Patch(color='red', label='K-d trees')
plt.legend(handles=[kd,bf])
plt.title("Execution time by dataset ")
plt.savefig("./figures/execution_time/kdTree_bruteForce")
plt.show()
